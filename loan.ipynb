# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
l1=pd.read_csv('loan.csv')
l1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
l1.shape
# Out:
# (614, 13)

# %%
l1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
l2=l1["Gender"].value_counts()
l2
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
l3=list(l1['Gender'].value_counts().keys())
l3
# Out:
# ['Male', 'Female']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(l1['Gender'].value_counts().keys()),list(l1['Gender'].value_counts()),color="g")
plt.grid(True)
plt.show()

plt.pie(l2,labels=l3,autopct="%0.1f%%")
plt.show()

# %%
l4=l1["Married"].value_counts()
l4
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
l5=list(l1['Married'].value_counts().keys())
l5
# Out:
# ['Yes', 'No']

# %%
plt.figure(figsize=(5,5))
plt.title("married")
plt.bar(list(l1['Married'].value_counts().keys()),list(l1['Married'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.title("Married")
plt.pie(l4,labels=l5,autopct="%0.1f%%")
plt.show()

# %%
l6=l1["Education"].value_counts()
l6
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
l7=list(l1['Education'].value_counts().keys())
l7
# Out:
# ['Graduate', 'Not Graduate']

# %%
plt.figure(figsize=(5,5))
plt.title("education")
plt.bar(list(l1['Education'].value_counts().keys()),list(l1['Education'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.title("education")
plt.pie(l6,labels=l7,autopct="%0.1f%%")
plt.show()

# %%
l8=l1["Self_Employed"].value_counts()
l8
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
l9=list(l1['Self_Employed'].value_counts().keys())
l9
# Out:
# ['No', 'Yes']

# %%
plt.figure(figsize=(5,5))
plt.title("Self Employment")
plt.bar(list(l1['Self_Employed'].value_counts().keys()),list(l1['Self_Employed'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.title("Self Employment")
plt.pie(l8,labels=l9,autopct="%0.1f%%")
plt.show()

# %%
l10=l1["Property_Area"].value_counts()
l10
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
l11=list(l1['Self_Employed'].value_counts().keys())
l11
# Out:
# ['No', 'Yes']

# %%
plt.figure(figsize=(5,5))
plt.title("Property Area")
plt.bar(list(l1['Property_Area'].value_counts().keys()),list(l1['Property_Area'].value_counts()),color="g")
plt.grid(True)
plt.show()
l12=["Semiurban","Urban","Rural"]
plt.title("Property Area")
plt.pie(l10,labels=l12,autopct="%0.1f%%")
plt.show()

# %%
l14=l1["Loan_Status"].value_counts()
l14
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
l15=list(l1['Loan_Status'].value_counts().keys())
l15
# Out:
# ['Y', 'N']

# %%
plt.figure(figsize=(5,5))
plt.title("Loan Status")
plt.bar(list(l1['Loan_Status'].value_counts().keys()),list(l1['Loan_Status'].value_counts()),color="g")
plt.grid(True)
plt.show()
plt.title("Loan Status")
plt.pie(l8,labels=l9,autopct="%0.1f%%")
plt.show()
